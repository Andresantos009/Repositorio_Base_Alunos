# %% [markdown]
# ### Minha Playlist

# %%
playlist = []
musica = input("Digite uma musica para adiconar na playlist")

for i in range(3):
    musica = input("Digite uma musica para adiconar na playlist")
    playlist.append(musica)

print(playlist)
