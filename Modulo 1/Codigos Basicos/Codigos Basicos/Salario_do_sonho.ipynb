# %% [markdown]
# ### Salario do Sonho

# %%
salario = 6000
gasolina = 200
internet = 200
alumentos = 1700
agua = 100
luz = 300
codominio = 700
entreterimento = 1600

quanto_sobra = salario - gasolina - internet - alumentos - agua - luz - codominio - entreterimento 
print('Vai sobrar no final do mes:', quanto_sobra)
# Out:
# Vai sobrar no final do mes: 1200
